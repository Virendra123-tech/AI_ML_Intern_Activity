# %% [markdown]
# Linear Regression_Housing_Data

# %% [markdown]
# In [2]:
#
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
#
#
#
#
#
#
#
#
#
# In [6]:
#
#
# df=pd.read_csv("Housing.csv")
#
#
#
#
#
#
#
#
#
#
# In [8]:
#
#
# df.head()
#
#
#
#
#
#
#
#
#
#
# Out[8]:
#
#
#
#
#
#
#
# price
# area
# bedrooms
# bathrooms
# stories
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus
#
#
#
#
# 0
# 13300000
# 7420
# 4
# 2
# 3
# yes
# no
# no
# no
# yes
# 2
# yes
# furnished
#
#
# 1
# 12250000
# 8960
# 4
# 4
# 4
# yes
# no
# no
# no
# yes
# 3
# no
# furnished
#
#
# 2
# 12250000
# 9960
# 3
# 2
# 2
# yes
# no
# yes
# no
# no
# 2
# yes
# semi-furnished
#
#
# 3
# 12215000
# 7500
# 4
# 2
# 2
# yes
# no
# yes
# no
# yes
# 3
# yes
# furnished
#
#
# 4
# 11410000
# 7420
# 4
# 1
# 2
# yes
# yes
# yes
# no
# yes
# 2
# no
# furnished
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [14]:
#
#
# df.info()
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB
#
#
#
#
#
#
#
#
#
#
# In [18]:
#
#
# df.shape
#
#
#
#
#
#
#
#
#
#
# Out[18]:
#
# (545, 13)
#
#
#
#
#
#
#
#
#
# In [20]:
#
#
# df.isnull().sum()
#
#
#
#
#
#
#
#
#
#
# Out[20]:
#
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64
#
#
#
#
#
#
#
#
#
# In [22]:
#
#
# df.duplicated().sum()
#
#
#
#
#
#
#
#
#
#
# Out[22]:
#
# 0
#
#
#
#
#
#
#
#
#
# In [24]:
#
#
# sns.pairplot(df)
#
#
#
#
#
#
#
#
#
#
# Out[24]:
#
# <seaborn.axisgrid.PairGrid at 0x23567fc3440>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [54]:
#
#
# sns.scatterplot(data=df,x='area',y='price')
# plt.show()
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [60]:
#
#
# sns.scatterplot(data=df,x='price',y='furnishingstatus')
# plt.show()
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [66]:
#
#
# #sns.countplot(data=df,x='bedrooms',y='area')
# #plt.show()
# sns.scatterplot(data=df,x='area',y='bedrooms')
# plt.show()
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [30]:
#
#
# # Droping Columns Here
# df.drop(columns=['stories'],inplace=True)
#
#
#
#
#
#
#
#
#
#
# In [32]:
#
#
# df.head()
#
#
#
#
#
#
#
#
#
#
# Out[32]:
#
#
#
#
#
#
#
# price
# area
# bedrooms
# bathrooms
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus
#
#
#
#
# 0
# 13300000
# 7420
# 4
# 2
# yes
# no
# no
# no
# yes
# 2
# yes
# furnished
#
#
# 1
# 12250000
# 8960
# 4
# 4
# yes
# no
# no
# no
# yes
# 3
# no
# furnished
#
#
# 2
# 12250000
# 9960
# 3
# 2
# yes
# no
# yes
# no
# no
# 2
# yes
# semi-furnished
#
#
# 3
# 12215000
# 7500
# 4
# 2
# yes
# no
# yes
# no
# yes
# 3
# yes
# furnished
#
#
# 4
# 11410000
# 7420
# 4
# 1
# yes
# yes
# yes
# no
# yes
# 2
# no
# furnished
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [36]:
#
#
# # Unique Values
# df.nunique()
#
#
#
#
#
#
#
#
#
#
# Out[36]:
#
# price               219
# area                284
# bedrooms              6
# bathrooms             4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64
#
#
#
#
#
#
#
#
#
# In [40]:
#
#
# df['furnishingstatus'].unique()
#
#
#
#
#
#
#
#
#
#
# Out[40]:
#
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)
#
#
#
#
#
#
#
#
#
# In [100]:
#
#
# df.head()
#
#
#
#
#
#
#
#
#
#
# Out[100]:
#
#
#
#
#
#
#
# price
# area
# bedrooms
# bathrooms
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus
#
#
#
#
# 0
# 13300000
# 7420
# 4
# 2
# yes
# no
# no
# no
# yes
# 2
# yes
# furnished
#
#
# 1
# 12250000
# 8960
# 4
# 4
# yes
# no
# no
# no
# yes
# 3
# no
# furnished
#
#
# 2
# 12250000
# 9960
# 3
# 2
# yes
# no
# yes
# no
# no
# 2
# yes
# semi-furnished
#
#
# 3
# 12215000
# 7500
# 4
# 2
# yes
# no
# yes
# no
# yes
# 3
# yes
# furnished
#
#
# 4
# 11410000
# 7420
# 4
# 1
# yes
# yes
# yes
# no
# yes
# 2
# no
# furnished
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [102]:
#
#
# from sklearn.preprocessing import LabelEncoder
#
#
#
#
#
#
#
#
#
#
# In [104]:
#
#
# encoder=LabelEncoder()
#
#
#
#
#
#
#
#
#
#
# In [115]:
#
#
# df['furnishingstatus']=encoder.fit_transform(df['furnishingstatus'])
#
#
#
#
#
#
#
#
#
#
# In [117]:
#
#
# df.head()
#
#
#
#
#
#
#
#
#
#
# Out[117]:
#
#
#
#
#
#
#
# price
# area
# bedrooms
# bathrooms
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus
#
#
#
#
# 0
# 13300000
# 7420
# 4
# 2
# yes
# no
# no
# no
# yes
# 2
# yes
# 0
#
#
# 1
# 12250000
# 8960
# 4
# 4
# yes
# no
# no
# no
# yes
# 3
# no
# 0
#
#
# 2
# 12250000
# 9960
# 3
# 2
# yes
# no
# yes
# no
# no
# 2
# yes
# 1
#
#
# 3
# 12215000
# 7500
# 4
# 2
# yes
# no
# yes
# no
# yes
# 3
# yes
# 0
#
#
# 4
# 11410000
# 7420
# 4
# 1
# yes
# yes
# yes
# no
# yes
# 2
# no
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [121]:
#
#
# df['mainroad']=encoder.fit_transform(df['mainroad'])
#
#
#
#
#
#
#
#
#
#
# In [123]:
#
#
# df['guestroom']=encoder.fit_transform(df['guestroom'])
#
#
#
#
#
#
#
#
#
#
# In [125]:
#
#
# df['basement']=encoder.fit_transform(df['basement'])
#
#
#
#
#
#
#
#
#
#
# In [127]:
#
#
# df['hotwaterheating']=encoder.fit_transform(df['hotwaterheating'])
#
#
#
#
#
#
#
#
#
#
# In [129]:
#
#
# df['airconditioning']=encoder.fit_transform(df['airconditioning'])
#
#
#
#
#
#
#
#
#
#
# In [131]:
#
#
# df['prefarea']=encoder.fit_transform(df['prefarea'])
#
#
#
#
#
#
#
#
#
#
# In [133]:
#
#
# df.head()
#
#
#
#
#
#
#
#
#
#
# Out[133]:
#
#
#
#
#
#
#
# price
# area
# bedrooms
# bathrooms
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus
#
#
#
#
# 0
# 13300000
# 7420
# 4
# 2
# 1
# 0
# 0
# 0
# 1
# 2
# 1
# 0
#
#
# 1
# 12250000
# 8960
# 4
# 4
# 1
# 0
# 0
# 0
# 1
# 3
# 0
# 0
#
#
# 2
# 12250000
# 9960
# 3
# 2
# 1
# 0
# 1
# 0
# 0
# 2
# 1
# 1
#
#
# 3
# 12215000
# 7500
# 4
# 2
# 1
# 0
# 1
# 0
# 1
# 3
# 1
# 0
#
#
# 4
# 11410000
# 7420
# 4
# 1
# 1
# 1
# 1
# 0
# 1
# 2
# 0
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [135]:
#
#
# # Scalling Process
#
#
#
#
#
#
#
#
#
#
# In [147]:
#
#
# from sklearn.preprocessing import MinMaxScaler
#
#
#
#
#
#
#
#
#
#
# In [149]:
#
#
# scaler=MinMaxScaler()
#
#
#
#
#
#
#
#
#
#
# In [153]:
#
#
# df['area']=scaler.fit_transform(df[['area']])
#
#
#
#
#
#
#
#
#
#
# In [155]:
#
#
# df.head()
#
#
#
#
#
#
#
#
#
#
# Out[155]:
#
#
#
#
#
#
#
# price
# area
# bedrooms
# bathrooms
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus
#
#
#
#
# 0
# 13300000
# 0.396564
# 4
# 2
# 1
# 0
# 0
# 0
# 1
# 2
# 1
# 0
#
#
# 1
# 12250000
# 0.502405
# 4
# 4
# 1
# 0
# 0
# 0
# 1
# 3
# 0
# 0
#
#
# 2
# 12250000
# 0.571134
# 3
# 2
# 1
# 0
# 1
# 0
# 0
# 2
# 1
# 1
#
#
# 3
# 12215000
# 0.402062
# 4
# 2
# 1
# 0
# 1
# 0
# 1
# 3
# 1
# 0
#
#
# 4
# 11410000
# 0.396564
# 4
# 1
# 1
# 1
# 1
# 0
# 1
# 2
# 0
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# In [159]:
#
#
# x=df.iloc[:,1:]
#
#
#
#
#
#
#
#
#
#
# In [163]:
#
#
# y=df.iloc[:,0]
#
#
#
#
#
#
#
#
#
#
# In [165]:
#
#
# from sklearn.model_selection import train_test_split
#
#
#
#
#
#
#
#
#
#
# In [167]:
#
#
# x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
#
#
#
#
#
#
#
#
#
#
# In [171]:
#
#
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_absolute_error,accuracy_score,mean_squared_error,r2_score
#
#
#
#
#
#
#
#
#
#
# In [173]:
#
#
# regression=LinearRegression()
#
#
#
#
#
#
#
#
#
#
# In [175]:
#
#
# regression.fit(x_train,y_train)
#
#
#
#
#
#
#
#
#
#
# Out[175]:
#
# LinearRegression()**In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.**  LinearRegression[?Documentation for LinearRegression](https://scikit-learn.org/1.4/modules/generated/sklearn.linear_model.LinearRegression.html)iFittedLinearRegression()
#
#
#
#
#
#
#
#
#
# In [177]:
#
#
# y_pred=regression.predict(x_test)
#
#
#
#
#
#
#
#
#
#
# In [179]:
#
#
# y_pred
#
#
#
#
#
#
#
#
#
#
# Out[179]:
#
# array([4996112.04648292, 7101578.81468009, 3261368.34016183,
#        4678734.96859002, 3721184.95778181, 3837495.28605767,
#        6099076.00598724, 6509770.75775847, 2860197.00537571,
#        2960309.41701355, 9153635.47085923, 2989492.07449949,
#        3435833.42730809, 2979266.0533413 , 3405190.68102913,
#        5418844.31873138, 2808296.92913051, 4847612.69760403,
#        4017845.29930266, 3696672.2448782 , 5057261.74036216,
#        6195685.99053039, 2926195.33325247, 4495729.30956445,
#        5189441.24829053, 7215472.25879021, 3291255.45201879,
#        5216135.01904566, 7939347.76494846, 3278725.07786246,
#        6476463.34709076, 3233075.72175686, 6678869.82981727,
#        4062509.75381432, 3634772.59291526, 6003965.2247886 ,
#        4504654.01352381, 4433893.1088177 , 3611780.71250314,
#        4908868.26847994, 4755904.27005744, 3896882.2990115 ,
#        7083811.30836513, 3969605.69659878, 3863242.61658089,
#        4592822.10313638, 6119778.36542818, 4048242.46567591,
#        3903630.27440387, 3350746.30256463, 6589268.88305934,
#        2977174.65814452, 4533230.86176369, 4265104.16236183,
#        3561149.52161985, 3006949.12109031, 6944215.16785352,
#        2878049.94505016, 4255114.07617963, 2959731.50142194,
#        4858007.07946954, 3557107.33197538, 5354654.93773562,
#        4370720.51604561, 4548103.3334361 , 4578555.81777884,
#        6098085.06947304, 3189759.66696031, 5025217.38242795,
#        6584401.19251561, 4516777.0592017 , 4628295.04242382,
#        4673149.97399396, 8363525.7748479 , 3881899.75670929,
#        5747565.66454422, 3789796.11418183, 5030817.0210852 ,
#        5344281.33719408, 4638410.69615676, 7689971.92251305,
#        3889738.33720344, 6784025.24612062, 4627263.23414724,
#        2722584.26479431, 6790931.90088225, 2966887.47662493,
#        3554701.00510107, 7925391.38118619, 8232405.50368199,
#        3172363.53604149, 6288784.25565684, 3822854.95875792,
#        3844568.46427258, 8033893.63129691, 5178354.25950102,
#        4427728.85917493, 5827025.27984577, 4384078.24961516,
#        6308250.35795783, 3703179.52089643, 6758174.9090498 ,
#        3252977.74733923, 5942621.27123889, 4723861.71745024,
#        4324134.33742876, 6544146.3894402 , 6625653.72989435,
#        6606524.39888871])
#
#
#
#
#
#
#
#
#
# In [185]:
#
#
# coeficient=regression.coef_
# coeficient
#
#
#
#
#
#
#
#
#
#
# Out[185]:
#
# array([3231465.21103223,  229249.80413991, 1218949.56790124,
#         481037.31630773,  310757.14459406,  178453.424548  ,
#         759887.50583522,  974906.74850884,  195118.21987211,
#         622419.21498842, -248334.31979503])
#
#
#
#
#
#
#
#
#
# In [191]:
#
#
# intercept=regression.intercept_
# intercept
#
#
#
#
#
#
#
#
#
#
# Out[191]:
#
# 820411.9163088268
#
#
#
#
#
#
#
#
#
# In [193]:
#
#
# mean_squared_error(y_test,y_pred)
#
#
#
#
#
#
#
#
#
#
# Out[193]:
#
# 1963480853867.7263
#
#
#
#
#
#
#
#
#
# In [195]:
#
#
# mean_absolute_error(y_test,y_pred)
#
#
#
#
#
#
#
#
#
#
# Out[195]:
#
# 1040013.5046890188
#
#
#
#
#
#
#
#
#
# In [197]:
#
#
# r2_score(y_test,y_pred)
#
#
#
#
#
#
#
#
#
#
# Out[197]:
#
# 0.6115434630111607
#
#
#
#
#
#
#
#
#
# In [209]:
#
#
# x.shape
#
#
#
#
#
#
#
#
#
#
# Out[209]:
#
# (545, 11)
#
#
#
#
#
#
#
#
#
# In [213]:
#
#
# y.shape
#
#
#
#
#
#
#
#
#
#
# Out[213]:
#
# (545,)
#
#
#
#
#
#
#
#
#
# In [ ]:
